# %% [markdown]
# <a href="https://colab.research.google.com/github/UdayasathwikaChitti1322/competitive_programming_lab/blob/main/kmpal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def compute_lps(pattern):
    m = len(pattern)
    lps = [0] * m

    length = 0  # length of previous longest prefix suffix
    i = 1

    print("\nBuilding LPS array:")
    while i < m:
        if pattern[i] == pattern[length]:
            length += 1
            lps[i] = length
            print(f"LPS[{i}] = {length}")
            i += 1
        else:
            if length != 0:
                length = lps[length - 1]
            else:
                lps[i] = 0
                print(f"LPS[{i}] = 0")
                i += 1

    return lps


def kmp_search(text, pattern):
    n = len(text)
    m = len(pattern)

    lps = compute_lps(pattern)
    print("\nLPS Array:", lps)
    print("--------------------------------------------------")

    i = 0  # index for text
    j = 0  # index for pattern
    matches = 0

    while i < n:
        print(f"Comparing text[{i}]='{text[i]}' with pattern[{j}]='{pattern[j]}'")

        if text[i] == pattern[j]:
            i += 1
            j += 1

        if j == m:
            print(f" Match Found at index {i - j} ✅")
            matches += 1
            j = lps[j - 1]

        elif i < n and text[i] != pattern[j]:
            print(" Mismatch ❌")

            if j != 0:
                j = lps[j - 1]
                print(f" Jump using LPS → j = {j}")
            else:
                i += 1

        print("--------------------------------------------------")

    print("\nRESULT:")
    print("Total Matches:", matches)

    if matches > 0:
        print("Pattern Found in Text ✅")
    else:
        print("Pattern Not Found ❌")


# 🔹 User Input
text = input("Enter the text: ")
pattern = input("Enter the pattern: ")

if len(pattern) > len(text):
    print("Pattern length should be less than or equal to text length")
else:
    kmp_search(text, pattern)
# Out:
# Enter the text: ABABDABACDABABCABAB
# Enter the pattern: ABABCABAB
#
# Building LPS array:
# LPS[1] = 0
# LPS[2] = 1
# LPS[3] = 2
# LPS[4] = 0
# LPS[5] = 1
# LPS[6] = 2
# LPS[7] = 3
# LPS[8] = 4
#
# LPS Array: [0, 0, 1, 2, 0, 1, 2, 3, 4]
# --------------------------------------------------
# Comparing text[0]='A' with pattern[0]='A'
# --------------------------------------------------
# Comparing text[1]='B' with pattern[1]='B'
# --------------------------------------------------
# Comparing text[2]='A' with pattern[2]='A'
# --------------------------------------------------
# Comparing text[3]='B' with pattern[3]='B'
#  Mismatch ❌
#  Jump using LPS → j = 2
# --------------------------------------------------
# Comparing text[4]='D' with pattern[2]='A'
#  Mismatch ❌
#  Jump using LPS → j = 0
# --------------------------------------------------
# Comparing text[4]='D' with pattern[0]='A'
#  Mismatch ❌
# --------------------------------------------------
# Comparing text[5]='A' with pattern[0]='A'
# --------------------------------------------------
# Comparing text[6]='B' with pattern[1]='B'
# --------------------------------------------------
# Comparing text[7]='A' with pattern[2]='A'
#  Mismatch ❌
#  Jump using LPS → j = 1
# --------------------------------------------------
# Comparing text[8]='C' with pattern[1]='B'
#  Mismatch ❌
#  Jump using LPS → j = 0
# --------------------------------------------------
# Comparing text[8]='C' with pattern[0]='A'
#  Mismatch ❌
# --------------------------------------------------
# Comparing text[9]='D' with pattern[0]='A'
#  Mismatch ❌
# --------------------------------------------------
# Comparing text[10]='A' with pattern[0]='A'
# --------------------------------------------------
# Comparing text[11]='B' with pattern[1]='B'
# --------------------------------------------------
# Comparing text[12]='A' with pattern[2]='A'
# --------------------------------------------------
# Comparing text[13]='B' with pattern[3]='B'
# --------------------------------------------------
# Comparing text[14]='C' with pattern[4]='C'
# --------------------------------------------------
# Comparing text[15]='A' with pattern[5]='A'
# --------------------------------------------------
# Comparing text[16]='B' with pattern[6]='B'
# --------------------------------------------------
# Comparing text[17]='A' with pattern[7]='A'
# --------------------------------------------------
# Comparing text[18]='B' with pattern[8]='B'
#  Match Found at index 10 ✅
# --------------------------------------------------
#
# RESULT:
# Total Matches: 1
# Pattern Found in Text ✅
